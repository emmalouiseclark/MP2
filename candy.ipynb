# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rawDF = pd.read_csv("candy.csv")

rawDF.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
rawDF.tail()
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 80   45.466282
# ...

# %%
rawDF.isna().sum()
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
print(rawDF.columns)
# Out:
# Index(['competitorname', 'chocolate', 'fruity', 'caramel', 'peanutyalmondy',
#        'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent',
#        'pricepercent', 'winpercent'],
#       dtype='object')

# %%
chocolate_candies = rawDF[rawDF['chocolate'] == 1]

print("Candies that have chocolate as an ingredient:")
print(chocolate_candies)
# Out:
# Candies that have chocolate as an ingredient:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                     100 Grand          1       0        1               0
# 1                  3 Musketeers          1       0        0               0
# 5                    Almond Joy          1       0        0               1
# 6                     Baby Ruth          1       0        1               1
# 10              Charleston Chew          1       0        0               0
# 22             HersheyÕs Kisses          1       0        0               0
# 23            HersheyÕs Krackel          1       0        0               0
# 24     HersheyÕs Milk Chocolate          1       0        0               0
# 25       HersheyÕs Special Dark          1       0        0               0
# 27                 Junior Mints          1       0        0               0
# 28                      Kit Kat          1       0        0               0
# ...

# %%
fruity_candies = rawDF[rawDF['fruity'] == 1]

print("Candies that have fruit as an ingredient:")
print(fruity_candies)
# Out:
# Candies that have fruit as an ingredient:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 4                     Air Heads          0       1        0               0
# 9            Caramel Apple Pops          0       1        1               0
# 11   Chewey Lemonhead Fruit Mix          0       1        0               0
# 12                     Chiclets          0       1        0               0
# 13                         Dots          0       1        0               0
# 14                     Dum Dums          0       1        0               0
# 15                  Fruit Chews          0       1        0               0
# 16                      Fun Dip          0       1        0               0
# 17                   Gobstopper          0       1        0               0
# 18            Haribo Gold Bears          0       1        0               0
# 20            Haribo Sour Bears          0       1        0               0
# ...

# %%
caramel_candies = rawDF[rawDF['caramel'] == 1]

print("Candies that have caramel as an ingredient:")
print(caramel_candies)
# Out:
# Candies that have caramel as an ingredient:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 6                    Baby Ruth          1       0        1               1
# 9           Caramel Apple Pops          0       1        1               0
# 35                   Milk Duds          1       0        1               0
# 36                   Milky Way          1       0        1               0
# 37          Milky Way Midnight          1       0        1               0
# 38    Milky Way Simply Caramel          1       0        1               0
# 56                        Rolo          1       0        1               0
# 64                    Snickers          1       0        1               1
# 65            Snickers Crisper          1       0        1               1
# 70                Sugar Babies          0       0        1               0
# ...

# %%
nutty_candies = rawDF[rawDF['peanutyalmondy'] == 1]

print("Candies that have nuts as an ingredient:")
print(nutty_candies)
# Out:
# Candies that have nuts as an ingredient:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 5                    Almond Joy          1       0        0               1
# 6                     Baby Ruth          1       0        1               1
# 7            Boston Baked Beans          0       0        0               1
# 32          Peanut butter M&MÕs          1       0        0               1
# 40                  Mr Good Bar          1       0        0               1
# 42          Nestle Butterfinger          1       0        0               1
# 46                       Payday          0       0        0               1
# 47                  Peanut M&Ms          1       0        0               1
# 51           ReeseÕs Miniatures          1       0        0               1
# 52    ReeseÕs Peanut Butter cup          1       0        0               1
# 53               ReeseÕs pieces          1       0        0               1
# ...

# %%
nougat_candies = rawDF[rawDF['nougat'] == 1]

print("Candies that have nougat as an ingredient:")
print(nougat_candies)
# Out:
# Candies that have nougat as an ingredient:
#         competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 1         3 Musketeers          1       0        0               0       1
# 6            Baby Ruth          1       0        1               1       1
# 10     Charleston Chew          1       0        0               0       1
# 36           Milky Way          1       0        1               0       1
# 37  Milky Way Midnight          1       0        1               0       1
# 46              Payday          0       0        0               1       1
# 64            Snickers          1       0        1               1       1
#
#     crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 1                  0     0    1         0         0.604         0.511
# 6                  0     0    1         0         0.604         0.767
# 10                 0     0    1         0         0.604         0.511
# ...

# %%
wafer_candies = rawDF[rawDF['crispedricewafer'] == 1]

print("Candies that have wafer as an ingredient:")
print(wafer_candies)
# Out:
# Candies that have wafer as an ingredient:
#        competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0           100 Grand          1       0        1               0       0
# 23  HersheyÕs Krackel          1       0        0               0       0
# 28            Kit Kat          1       0        0               0       0
# 43      Nestle Crunch          1       0        0               0       0
# 65   Snickers Crisper          1       0        1               1       0
# 79               Twix          1       0        1               0       0
# 84           Whoppers          1       0        0               0       0
#
#     crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                  1     0    1         0         0.732         0.860
# 23                 1     0    1         0         0.430         0.918
# 28                 1     0    1         0         0.313         0.511
# ...

# %%
hard_candies = rawDF[rawDF['hard'] == 1]

print("Candies that are hard:")
print(hard_candies)
# Out:
# Candies that are hard:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 14                    Dum Dums          0       1        0               0
# 16                     Fun Dip          0       1        0               0
# 17                  Gobstopper          0       1        0               0
# 26                  Jawbusters          0       1        0               0
# 30                   Lemonhead          0       1        0               0
# 41                       Nerds          0       1        0               0
# 49                   Pop Rocks          0       1        0               0
# 55                    Ring pop          0       1        0               0
# 57           Root Beer Barrels          0       0        0               0
# 58                       Runts          0       1        0               0
# 63              Smarties candy          0       1        0               0
# ...

# %%
bar_candies = rawDF[rawDF['bar'] == 1]

print("Candies that are in bar form:")

print(bar_candies)
# Out:
# Candies that are in bar form:
#               competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                  100 Grand          1       0        1               0
# 1               3 Musketeers          1       0        0               0
# 5                 Almond Joy          1       0        0               1
# 6                  Baby Ruth          1       0        1               1
# 10           Charleston Chew          1       0        0               0
# 23         HersheyÕs Krackel          1       0        0               0
# 24  HersheyÕs Milk Chocolate          1       0        0               0
# 25    HersheyÕs Special Dark          1       0        0               0
# 28                   Kit Kat          1       0        0               0
# 36                 Milky Way          1       0        1               0
# 37        Milky Way Midnight          1       0        1               0
# ...

# %%
candy_sums = rawDF[['chocolate', 'fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar']].sum()

plt.figure(figsize=(10, 8))
plt.pie(candy_sums, labels=candy_sums.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Candies Based on Ingredients')
plt.axis('equal')  
plt.show()

# %%
# Find the candy with the highest win percentage
most_popular_candy = rawDF.loc[rawDF['winpercent'].idxmax()]

print("The most popular candy is:")
print(most_popular_candy)
# Out:
# The most popular candy is:
# competitorname      ReeseÕs Peanut Butter cup
# chocolate                                   1
# fruity                                      0
# caramel                                     0
# peanutyalmondy                              1
# nougat                                      0
# crispedricewafer                            0
# hard                                        0
# bar                                         0
# pluribus                                    0
# sugarpercent                             0.72
# pricepercent                            0.651
# winpercent                           84.18029
# Name: 52, dtype: object

# %%
# Find the candy with the lowest win percentage
least_popular_candy = rawDF.loc[rawDF['winpercent'].idxmin()]

print("The least popular candy is:")
print(least_popular_candy)
# Out:
# The least popular candy is:
# competitorname      Nik L Nip
# chocolate                   0
# fruity                      1
# caramel                     0
# peanutyalmondy              0
# nougat                      0
# crispedricewafer            0
# hard                        0
# bar                         0
# pluribus                    1
# sugarpercent            0.197
# pricepercent            0.976
# winpercent          22.445341
# Name: 44, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_candies = rawDF.sort_values('winpercent', ascending=False).head(10)
# Creating a blue gradient palette for win percentiles and reversing the order
palette = sns.color_palette("Blues", len(top_candies))[::-1]
sns.barplot(x='winpercent', y='competitorname', data=top_candies, palette=palette)
plt.xlabel('Win Percentage')
plt.ylabel('Candy')
plt.title('Top 10 Most Popular Candies')
plt.show()
# Out:
# /var/folders/_n/88nsmwlj1k5fmf9psfmkbhfc0000gn/T/ipykernel_21291/1288599112.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='winpercent', y='competitorname', data=top_candies, palette=palette)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bottom_candies = rawDF.sort_values('winpercent').head(10)
# Creating a red gradient palette and reversing the order
palette = sns.color_palette("Reds", len(bottom_candies))[::-1]
sns.barplot(x='winpercent', y='competitorname', data=bottom_candies, palette=palette)
plt.xlabel('Win Percentage')
plt.ylabel('Candy')
plt.title('Top 10 Least Popular Candies')
plt.show()
# Out:
# /var/folders/_n/88nsmwlj1k5fmf9psfmkbhfc0000gn/T/ipykernel_21291/71604898.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='winpercent', y='competitorname', data=bottom_candies, palette=palette)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_candies = rawDF.sort_values('pricepercent', ascending=False).head(10)
# Creating a blue gradient palette for price percentiles and reversing the order
palette = sns.color_palette("Greens", len(top_candies))[::-1]
sns.barplot(x='pricepercent', y='competitorname', data=top_candies, palette=palette)
plt.xlabel('Price Percentile')
plt.ylabel('Candy')
plt.title('Top 10 Candies with Highest Price Percentiles')
plt.show()
# Out:
# /var/folders/_n/88nsmwlj1k5fmf9psfmkbhfc0000gn/T/ipykernel_21291/521739148.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pricepercent', y='competitorname', data=top_candies, palette=palette)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

bottom_candies = rawDF.sort_values('pricepercent').head(10)
# Creating a blue gradient palette for price percentiles and reversing the order
palette = sns.color_palette("Purples", len(bottom_candies))[::-1]
sns.barplot(x='pricepercent', y='competitorname', data=bottom_candies, palette=palette)
plt.xlabel('Price Percentile')
plt.ylabel('Candy')
plt.title('Top 10 Candies with Lowest Price Percentiles')
plt.show()
# Out:
# /var/folders/_n/88nsmwlj1k5fmf9psfmkbhfc0000gn/T/ipykernel_21291/3581156899.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='pricepercent', y='competitorname', data=bottom_candies, palette=palette)

# %%
import matplotlib.pyplot as plt

# Assuming rawDF is defined and contains the data

plt.figure(figsize=(10, 6))
plt.scatter(rawDF['pricepercent'], rawDF['winpercent'])
plt.xlabel('Price Percent')
plt.ylabel('Win Percent')
plt.title('Relationship between Price Percent and Win Percent')
plt.show()
